# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csvpath='/Users/lauradu/Downloads/youtube-new/USvideos.csv'
Youtube_df=pd.read_csv (csvpath)
Youtube_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
Youtube_df.count()
# Out:
# video_id                  40949
# trending_date             40949
# title                     40949
# channel_title             40949
# category_id               40949
# publish_time              40949
# tags                      40949
# views                     40949
# likes                     40949
# dislikes                  40949
# comment_count             40949
# thumbnail_link            40949
# comments_disabled         40949
# ratings_disabled          40949
# video_error_or_removed    40949
# description               40379
# dtype: int64

# %%
Youtube_df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
clean_Youtube_df = Youtube_df.dropna(how="any")
clean_Youtube_df.count()
# Out:
# video_id                  40379
# trending_date             40379
# title                     40379
# channel_title             40379
# category_id               40379
# publish_time              40379
# tags                      40379
# views                     40379
# likes                     40379
# dislikes                  40379
# comment_count             40379
# thumbnail_link            40379
# comments_disabled         40379
# ratings_disabled          40379
# video_error_or_removed    40379
# description               40379
# dtype: int64

# %%
category_Youtube_df=clean_Youtube_df.loc[clean_Youtube_df["category_id"] == 22, :]
category_Youtube_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 35     0mlNzVSJrT0      17.14.11
# 44     STI2fI7sKMo      17.14.11
# 54     KODzih-pYlU      17.14.11
# 66     8mhTWqWlQzU      17.14.11
# 85     pa_oUisZZy0      17.14.11
# 100    fCTKDn3Q8xQ      17.14.11
# 119    _dhneCO4YEE      17.14.11
# 120    EYkEshCOhEU      17.14.11
# 123    Eg_kW5fw6qU      17.14.11
# 138    6Detw08jRhs      17.14.11
# 154    P4YJwy_T9pM      17.14.11
# 180    1640fZpYBSY      17.14.11
# 182    7m630xvAJtA      17.14.11
# 191    6ixU_vdE0Es      17.14.11
# 192    wRGldR_SQAA      17.14.11
# 198    6hTzM1BPdU8      17.14.11
# 217    2kyS6SvSYSE      17.15.11
# 296    ijJPFowBsBc      17.15.11
# 303    0mlNzVSJrT0      17.15.11
# 309    STI2fI7sKMo      17.15.11
# 318    9KIP-Ncp2jU      17.15.11
# 319    KODzih-pYlU      17.15.11
# 325    8mhTWqWlQzU      17.15.11
# 340    Fyyua5JzD9w      17.15.11
# 341    pa_oUisZZy0      17.15.11
# 366    fCTKDn3Q8xQ      17.15.11
# ...

# %%
Category_Youtube_df = Youtube_df.groupby('category_id').sum()
Category_Youtube_df.head()
# Out:
#                    views       likes  dislikes  comment_count  \
# category_id
# 1             7284156721   165997476   6075148       17887060
# 2              520690717     4245656    243010         784447
# 10           40132892190  1416838584  51179008      125296396
# 15             764651989    19370702    527379        2660705
# 17            4404456673    98621211   5133551       11192155
#
#              comments_disabled  ratings_disabled  video_error_or_removed
# category_id
# 1                         28.0              14.0                    13.0
# 2                          5.0              10.0                     0.0
# 10                         9.0              24.0                     0.0
# 15                         4.0               0.0                     0.0
# 17                        28.0              17.0                     2.0

# %%
Category_Youtube_df=Category_Youtube_df.reset_index()
Category_Youtube_df.head()
# Out:
#    category_id        views       likes  dislikes  comment_count  \
# 0            1   7284156721   165997476   6075148       17887060
# 1            2    520690717     4245656    243010         784447
# 2           10  40132892190  1416838584  51179008      125296396
# 3           15    764651989    19370702    527379        2660705
# 4           17   4404456673    98621211   5133551       11192155
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0               28.0              14.0                    13.0
# 1                5.0              10.0                     0.0
# 2                9.0              24.0                     0.0
# 3                4.0               0.0                     0.0
# 4               28.0              17.0                     2.0

# %%
Category_Youtube_df['Percentage_likes'] =Category_Youtube_df.likes/Category_Youtube_df.views*100
Category_Youtube_df.head()
# Out:
#    category_id        views       likes  dislikes  comment_count  \
# 0            1   7284156721   165997476   6075148       17887060
# 1            2    520690717     4245656    243010         784447
# 2           10  40132892190  1416838584  51179008      125296396
# 3           15    764651989    19370702    527379        2660705
# 4           17   4404456673    98621211   5133551       11192155
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0               28.0              14.0                    13.0
# 1                5.0              10.0                     0.0
# 2                9.0              24.0                     0.0
# 3                4.0               0.0                     0.0
# 4               28.0              17.0                     2.0
#
#    Percentage_likes
# 0          2.278884
# 1          0.815389
# 2          3.530368
# 3          2.533270
# 4          2.239123

# %%
Category_Youtube_df['Percentage_dislikes'] =Category_Youtube_df.dislikes/Category_Youtube_df.views*100
Category_Youtube_df.head()
# Out:
#    category_id        views       likes  dislikes  comment_count  \
# 0            1   7284156721   165997476   6075148       17887060
# 1            2    520690717     4245656    243010         784447
# 2           10  40132892190  1416838584  51179008      125296396
# 3           15    764651989    19370702    527379        2660705
# 4           17   4404456673    98621211   5133551       11192155
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0               28.0              14.0                    13.0
# 1                5.0              10.0                     0.0
# 2                9.0              24.0                     0.0
# 3                4.0               0.0                     0.0
# 4               28.0              17.0                     2.0
#
#    Percentage_likes  Percentage_dislikes
# 0          2.278884             0.083402
# 1          0.815389             0.046671
# 2          3.530368             0.127524
# ...

# %%
Category_Youtube_df.shape
# Out:
# (16, 10)

# %%
Category_Youtube_df = Category_Youtube_df.sort_values(by='Percentage_likes', ascending=False)
Category_Youtube_df
# Out:
#     category_id        views       likes  dislikes  comment_count  \
# 14           29    168941392    14815646   3310381        4808797
# 8            23   5117426208   216346746   7230391       22545582
# 12           27   1180629990    49257772   1351972        5442242
# 11           26   4078545064   162880075   5473899       23149550
# 7            22   4917191726   186615999  10187901       24778032
# 2            10  40132892190  1416838584  51179008      125296396
# 6            20   2141218625    69038284   9184466       14740713
# 9            24  20604388195   530516491  42987663       73566498
# 3            15    764651989    19370702    527379        2660705
# 13           28   3487756816    82532638   4548402       11989926
# 0             1   7284156721   165997476   6075148       17887060
# 4            17   4404456673    98621211   5133551       11192155
# 15           43     51501058     1082639     24508          95117
# ...

# %%
import seaborn as sns

cat_data = {2:'Autos & Vehicles',
           1:'Film & Animation',
           10:'Music',
           15:'Pets & Animals',
           17:'Sports',
           18:'Short Movies',
           19:'Travel & Events',
           20:'Gaming',
           21:'Videoblogging',
           22:'People & Blogs',
           23:'Comedy',
           24:'Entertainment',
           25:'News & Politics',
           26:'Howto & Style',
           27:'Education',
           28:'Science & Technology',
           29:'Nonprofits & Activism',
           30:'Movies',
           31:'Anime/Animation',
           32:'Action/Adventure',
           33:'Classics',
           34:'Comedy',
           35:'Documentary',
           36:'Drama',
           37:'Family',
           38:'Foreign',
           39:'Horror',
           40:'Sci-Fi/Fantasy',
           41:'Thriller',
           42:'Shorts',
           43:'Shows',
           44:'Trailers'}
cat_id = list(Category_Youtube_df['category_id'])
objects = []
for cat in cat_id:
   for index, name in cat_data.items():
       if index == int(cat):
           objects.append(name)

plt.figure(figsize=(10,6))
sns.barplot(y=Category_Youtube_df['Percentage_likes'], x=objects, alpha=0.6)
plt.xticks(rotation=90)
plt.yticks([0,2,4,6,8],['0%','2%','4%','6%','8%'])
plt.title("Youtube Percentage of Likes", fontsize=16)
plt.ylabel("Video Percentage Likes", fontsize=16)
plt.savefig('Percentage of Likes.png', bbox_inches='tight', dpi=100)
plt.show()

# %%
import seaborn as sns

cat_data = {2:'Autos & Vehicles',
           1:'Film & Animation',
           10:'Music',
           15:'Pets & Animals',
           17:'Sports',
           18:'Short Movies',
           19:'Travel & Events',
           20:'Gaming',
           21:'Videoblogging',
           22:'People & Blogs',
           23:'Comedy',
           24:'Entertainment',
           25:'News & Politics',
           26:'Howto & Style',
           27:'Education',
           28:'Science & Technology',
           29:'Nonprofits & Activism',
           30:'Movies',
           31:'Anime/Animation',
           32:'Action/Adventure',
           33:'Classics',
           34:'Comedy',
           35:'Documentary',
           36:'Drama',
           37:'Family',
           38:'Foreign',
           39:'Horror',
           40:'Sci-Fi/Fantasy',
           41:'Thriller',
           42:'Shorts',
           43:'Shows',
           44:'Trailers'}
cat_id = list(Category_Youtube_df['category_id'])
objects = []
for cat in cat_id:
   for index, name in cat_data.items():
       if index == int(cat):
           objects.append(name)

plt.figure(figsize=(10,6))
sns.barplot(y=Category_Youtube_df['Percentage_dislikes'], x=objects, alpha=0.6)
plt.xticks(rotation=90)
plt.yticks([0.00,0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00],['0.00%','0.25%','0.50%','0.75%','1.00%','1.25%','1.50%','1.75%','2.00%'])
plt.title("Youtube Percentage of dislikes", fontsize=16)
plt.ylabel("Video Percentage dislikes", fontsize=16)
plt.savefig('Percentage of Dislikes.png', bbox_inches='tight', dpi=100)
plt.show()

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(13, 10))

# Plot the total schools per city
sns.set_color_codes("pastel")
sns.barplot(x=objects, y='Percentage_likes', data=Category_Youtube_df,
           label="likes percentage", color="b")
plt.xticks(rotation=90)
plt.yticks([0,2,4,6,8],['0%','2%','4%','6%','8%'])

# Plot the total community schools per city
sns.set_color_codes("muted")
sns.barplot(x=objects, y="Percentage_dislikes", data=Category_Youtube_df,
           label="dislikes percentage", color="r")
plt.savefig('Comparison.png', bbox_inches='tight', dpi=100)
plt.legend()

# %%
objects
# Out:
# ['Film & Animation',
#  'Autos & Vehicles',
#  'Music',
#  'Pets & Animals',
#  'Sports',
#  'Travel & Events',
#  'Gaming',
#  'People & Blogs',
#  'Comedy',
#  'Entertainment',
#  'News & Politics',
#  'Howto & Style',
#  'Education',
#  'Science & Technology',
#  'Nonprofits & Activism',
#  'Shows']
